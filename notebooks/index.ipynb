# %% [markdown]
# # 📚 Data Structures & Algorithms Interactive Learning
#
# Welcome to the interactive Jupyter notebook companion for **"A First Course on Data Structures in Python"** by Donald R. Sheehy!
#
# This collection of notebooks provides hands-on, interactive learning experiences for each chapter, complete with visualizations, step-by-step demonstrations, and performance analysis.
#
# ## 🎯 Learning Objectives
#
# By the end of this course, you'll understand:
# - Core data structures and their implementations
# - Algorithm analysis and complexity theory
# - Real-world applications and performance considerations
# - Best practices for writing efficient, maintainable code
#
# ## 📖 Course Overview
#
# This course is structured into 22 chapters, progressing from fundamental concepts to advanced algorithms:

# %% [markdown]
# ## 📑 Chapter Navigation
#
# ### Foundations (Chapters 1-4)
# - **[Chapter 1: Overview](chapter_01_overview.ipynb)** - Introduction to data structures and algorithms
# - **[Chapter 2: Basic Python](chapter_02_basic_python.ipynb)** - Python fundamentals for DSA
# - **[Chapter 3: Object-Oriented Programming](chapter_03_oop.ipynb)** - Classes, inheritance, and design patterns
# - **[Chapter 4: Testing](chapter_04_testing.ipynb)** - Unit testing and debugging techniques
#
# ### Analysis & Complexity (Chapters 5-6)
# - **[Chapter 5: Running Time Analysis](chapter_05_complexity.ipynb)** - Big O notation and complexity analysis
# - **[Chapter 6: Stacks & Queues](chapter_06_stacks_queues.ipynb)** - Linear data structures and their applications
#
# ### Linear Structures (Chapters 7-11)
# - **[Chapter 7: Deques & Linked Lists](chapter_07_deques_linked_lists.ipynb)** - Dynamic arrays and linked implementations
# - **[Chapter 8: Doubly Linked Lists](chapter_08_doubly_linked_lists.ipynb)** - Bidirectional traversal and operations
# - **[Chapter 9: Recursion](chapter_09_recursion.ipynb)** - Recursive algorithms and problem-solving
# - **[Chapter 10: Dynamic Programming](chapter_10_dynamic_programming.ipynb)** - Optimal substructure and memoization
# - **[Chapter 11: Binary Search](chapter_11_binary_search.ipynb)** - Divide-and-conquer searching
#
# ### Advanced Algorithms (Chapters 12-14)
# - **[Chapter 12-14: Sorting & Selection Algorithms](chapter_12_14_sorting.ipynb)** - Comprehensive sorting analysis and quickselect
# - **[Chapter 12: Sorting Algorithms](chapter_12_sorting_algorithms.ipynb)** - Comparison-based sorting techniques
# - **[Chapter 13: Divide & Conquer Sorting](chapter_13_sorting_divide_conquer.ipynb)** - Mergesort and Quicksort
# - **[Chapter 14: Selection Algorithms](chapter_14_selection.ipynb)** - Finding order statistics efficiently
#
# ### Data Structures (Chapters 15-19)
# - **[Chapter 15: Hash Tables](chapter_15_hash_tables.ipynb)** - Interactive hash functions, collision resolution, and performance analysis
# - **[Chapter 16-18: Trees, BSTs & AVL](chapter_16_18_trees.ipynb)** - Interactive tree structures, traversals, and balancing
# - **[Chapter 16: Trees](chapter_16_trees.ipynb)** - Tree structures and traversals
# - **[Chapter 17: Binary Search Trees](chapter_17_bst.ipynb)** - Ordered mappings and BST operations
# - **[Chapter 18: Balanced Trees](chapter_18_balanced_trees.ipynb)** - AVL trees and self-balancing
# - **[Chapter 19: Priority Queues & Heaps](chapter_19_heaps.ipynb)** - Interactive heap operations and priority queue applications
#
# ### Graph Algorithms (Chapters 20-22)
# - **[Chapter 20-21: Graph Algorithms](chapter_20_21_graphs.ipynb)** - Interactive graph representations, traversals, shortest paths, MSTs
# - **[Chapter 21: Advanced Graph Search](chapter_21_graph_search.ipynb)** - Shortest paths, MSTs, and flow networks
# - **[Chapter 22: Union-Find](chapter_22_union_find.ipynb)** - Disjoint sets and connectivity

# %% [markdown]
# ## 🚀 Getting Started
#
# ### Installation
#
# 1. **Clone the repository:**
#    ```bash
#    git clone https://github.com/yourusername/data-structures-python.git
#    cd data-structures-python
#    ```
#
# 2. **Install dependencies:**
#    ```bash
#    pip install -r requirements.txt
#    ```
#
# 3. **Launch Jupyter:**
#    ```bash
#    jupyter notebook notebooks/
#    ```
#
# ### Learning Path Recommendations
#
# - **Beginners**: Start with Chapters 1-6 for foundations
# - **Intermediate**: Focus on Chapters 7-14 for algorithms
# - **Advanced**: Dive into Chapters 15-22 for complex data structures
# - **Interview Prep**: Review Chapters 10, 12-14, 15, 19-21
#
# ### Tips for Success
# - Run all code cells in order
# - Experiment with parameters and inputs
# - Study the visualizations carefully
# - Complete the exercises in each notebook

# %%
# Quick setup verification
import sys
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import networkx as nx

print(f"Python version: {sys.version}")
print("✅ All required packages imported successfully!")
print("\n🎯 Ready to explore data structures and algorithms!")
print("\n📊 Sample visualization test:")

# Simple complexity comparison visualization
n = np.linspace(1, 100, 100)
plt.figure(figsize=(10, 6))
plt.plot(n, n, label='O(n) - Linear', color='blue')
plt.plot(n, n * np.log(n), label='O(n log n) - Linearithmic', color='green')
plt.plot(n, n**2, label='O(n²) - Quadratic', color='red')
plt.plot(n, 2**n, label='O(2^n) - Exponential', color='purple')
plt.yscale('log')
plt.xlabel('Input Size (n)')
plt.ylabel('Operations (log scale)')
plt.title('Algorithm Complexity Comparison')
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()
# Out:
# Python version: 3.14.2 (main, Dec  5 2025, 16:49:16) [Clang 17.0.0 (clang-1700.6.3.2)]
# ✅ All required packages imported successfully!
#
# 🎯 Ready to explore data structures and algorithms!
#
# 📊 Sample visualization test:

# %% [markdown]
# ## 📈 Progress Tracking
#
# Use this interactive widget to track your learning progress:

# %%
import ipywidgets as widgets
from IPython.display import display, HTML

# Progress tracking widget
chapters = [
    "Chapter 1: Overview",
    "Chapter 2: Basic Python", 
    "Chapter 3: OOP",
    "Chapter 4: Testing",
    "Chapter 5: Complexity Analysis",
    "Chapter 6: Stacks & Queues",
    "Chapter 7: Deques & Linked Lists",
    "Chapter 8: Doubly Linked Lists",
    "Chapter 9: Recursion",
    "Chapter 10: Dynamic Programming",
    "Chapter 11: Binary Search",
    "Chapter 12: Sorting",
    "Chapter 13: Divide & Conquer Sorting",
    "Chapter 14: Selection",
    "Chapter 15: Hash Tables",
    "Chapter 16: Trees",
    "Chapter 17: BSTs",
    "Chapter 18: Balanced Trees",
    "Chapter 19: Priority Queues",
    "Chapter 20: Graphs",
    "Chapter 21: Advanced Graph Search",
    "Chapter 22: Union-Find"
]

progress_widgets = []
for chapter in chapters:
    checkbox = widgets.Checkbox(value=False, description=chapter)
    progress_widgets.append(checkbox)

progress_box = widgets.VBox(progress_widgets)
display(HTML("<h3>📝 Mark chapters as completed:</h3>"))
display(progress_box)

# Progress summary
def update_progress(*args):
    completed = sum(w.value for w in progress_widgets)
    total = len(progress_widgets)
    percentage = (completed / total) * 100
    print(f"\r📊 Progress: {completed}/{total} chapters completed ({percentage:.1f}%)", end='')

for widget in progress_widgets:
    widget.observe(update_progress, names='value')
    
update_progress()
# Out:
# <h3>📝 Mark chapters as completed:</h3>
# ...
# 📊 Progress: 0/22 chapters completed (0.0%)

# %% [markdown]
# ## 🔧 Additional Resources
#
# - **[Main Repository](https://github.com/exploreborders/Data_Structures)** - Source code and documentation
# - **[Book Companion](https://donsheehy.github.io/datastructures/fullbook.pdf)** - Original textbook and resources
# - **[Algorithm Visualizations](https://visualgo.net/)** - Interactive algorithm visualizations
# - **[LeetCode](https://leetcode.com/)** - Practice coding problems
# - **[Big O Cheat Sheet](https://www.bigocheatsheet.com/)** - Complexity reference
#
# ## 🤝 Contributing
#
# Found an issue or want to contribute?
# - Report bugs and suggest improvements
# - Submit pull requests for new notebooks or enhancements
# - Share your learning experiences and feedback
#
# ## 📄 License
#
# This project is licensed under the MIT License - see the [LICENSE](../LICENSE) file for details.
#
# ---
#
# **🎓 Happy Learning! May your algorithms always be efficient and your data structures well-balanced.**
