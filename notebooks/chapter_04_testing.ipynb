# %% [markdown]
# # 🧪 Chapter 4: Testing - Unit Testing and Debugging Techniques
#
# Testing is an essential part of software development. In this notebook, you'll learn how to write effective tests and debug your code.
#
# ## 🎯 Learning Objectives
#
# By the end of this notebook, you'll be able to:
# - Understand the importance of testing in software development
# - Write unit tests using Python's built-in `unittest` module
# - Test functions and classes with different types of assertions
# - Handle expected exceptions in tests
# - Use debugging techniques to identify and fix issues
#
# ## 🚀 Let's Get Started!

# %%
# Import required libraries
import sys
import os
sys.path.append('../')

import unittest
from chapter_04_testing.tests.test_testing_concepts import (
    TestCalculator,
    TestStack,
    TestStringProcessor,
    TestBankAccount
)

print("✅ Libraries imported successfully!")
print("🎯 Ready to learn Testing and Debugging!")
# Out:
# ✅ Libraries imported successfully!
# 🎯 Ready to learn Testing and Debugging!

# %% [markdown]
# ## 📊 Running Tests
#
# Let's run the existing tests using Python's `unittest` module:

# %%
# Run all tests from chapter_04_testing
test_suite = unittest.TestLoader().discover(
    os.path.join('../', 'chapter_04_testing', 'tests')
)

print("Running all tests...")
print("=" * 50)
test_runner = unittest.TextTestRunner(verbosity=2)
test_runner.run(test_suite)
# Out:
# test_balance_unchanged_after_failed_operations (test_testing_concepts.TestBankAccount.test_balance_unchanged_after_failed_operations)
# Test that balance doesn't change after failed operations. ... ok
# test_deposit_increases_balance (test_testing_concepts.TestBankAccount.test_deposit_increases_balance)
# Test that deposit increases balance. ... ok
# test_deposit_zero_or_negative_raises_error (test_testing_concepts.TestBankAccount.test_deposit_zero_or_negative_raises_error)
# Test that depositing zero or negative amounts raises error. ... ok
# test_initial_balance (test_testing_concepts.TestBankAccount.test_initial_balance)
# Test account starts with correct balance. ... ok
# test_negative_initial_balance_raises_error (test_testing_concepts.TestBankAccount.test_negative_initial_balance_raises_error)
# Test that negative initial balance raises ValueError. ... ok
# test_transaction_history (test_testing_concepts.TestBankAccount.test_transaction_history)
# Test that transactions are recorded in history. ... ok
# test_withdraw_decreases_balance (test_testing_concepts.TestBankAccount.test_withdraw_decreases_balance)
# Test that withdrawal decreases balance. ... ok
# test_withdraw_insufficient_funds_raises_error (test_testing_concepts.TestBankAccount.test_withdraw_insufficient_funds_raises_error)
# Test that withdrawing more than balance raises error. ... ok
# test_withdraw_zero_or_negative_raises_error (test_testing_concepts.TestBankAccount.test_withdraw_zero_or_negative_raises_error)
# Test that withdrawing zero or negative amounts raises error. ... ok
# test_addition (test_testing_concepts.TestCalculator.test_addition)
# Test calculator addition. ... ok
# test_division (test_testing_concepts.TestCalculator.test_division)
# Test calculator division. ... ok
# test_division_by_zero (test_testing_concepts.TestCalculator.test_division_by_zero)
# Test division by zero raises error. ... ok
# test_history_tracking (test_testing_concepts.TestCalculator.test_history_tracking)
# Test that history is maintained correctly. ... ok
# test_multiplication (test_testing_concepts.TestCalculator.test_multiplication)
# Test calculator multiplication. ... ok
# test_subtraction (test_testing_concepts.TestCalculator.test_subtraction)
# Test calculator subtraction. ... ok
# test_new_stack_is_empty (test_testing_concepts.TestStack.test_new_stack_is_empty)
# Test that a new stack is empty. ... ok
# test_peek_does_not_remove (test_testing_concepts.TestStack.test_peek_does_not_remove)
# Test that peek returns top item without removing it. ... ok
# test_peek_empty_stack_raises_error (test_testing_concepts.TestStack.test_peek_empty_stack_raises_error)
# Test that peeking empty stack raises IndexError. ... ok
# test_pop_empty_stack_raises_error (test_testing_concepts.TestStack.test_pop_empty_stack_raises_error)
# Test that popping empty stack raises IndexError. ... ok
# test_push_increases_size (test_testing_concepts.TestStack.test_push_increases_size)
# Test that push increases stack size. ... ok
# test_push_pop_roundtrip (test_testing_concepts.TestStack.test_push_pop_roundtrip)
# Test push and pop maintain order (LIFO). ... ok
# test_capitalize_words (test_testing_concepts.TestStringProcessor.test_capitalize_words)
# Test capitalizing first letter of each word. ... ok
# test_count_words_empty (test_testing_concepts.TestStringProcessor.test_count_words_empty)
# Test counting words in empty string. ... ok
# test_count_words_multiple_spaces (test_testing_concepts.TestStringProcessor.test_count_words_multiple_spaces)
# Test handling multiple spaces between words. ... ok
# test_count_words_normal (test_testing_concepts.TestStringProcessor.test_count_words_normal)
# Test counting words in normal text. ... ok
# test_reverse_empty_string (test_testing_concepts.TestStringProcessor.test_reverse_empty_string)
# Test reversing an empty string. ... ok
# test_reverse_non_string_raises_error (test_testing_concepts.TestStringProcessor.test_reverse_non_string_raises_error)
# Test that non-string input raises TypeError. ... ok
# test_reverse_normal_string (test_testing_concepts.TestStringProcessor.test_reverse_normal_string)
# Test reversing a normal string. ... ok
# test_reverse_single_character (test_testing_concepts.TestStringProcessor.test_reverse_single_character)
# Test reversing a single character. ... ok
# test_reverse_unicode (test_testing_concepts.TestStringProcessor.test_reverse_unicode)
# Test reversing unicode strings. ... ok
#
# ----------------------------------------------------------------------
# Ran 30 tests in 0.025s
#
# OK
# Running all tests...
# ==================================================
# ✓ TestBankAccount.test_balance_unchanged_after_failed_operations
# ✓ TestBankAccount.test_deposit_increases_balance
# ✓ TestBankAccount.test_deposit_zero_or_negative_raises_error
# ✓ TestBankAccount.test_initial_balance
# ✓ TestBankAccount.test_negative_initial_balance_raises_error
# ✓ TestBankAccount.test_transaction_history
# ✓ TestBankAccount.test_withdraw_decreases_balance
# ✓ TestBankAccount.test_withdraw_insufficient_funds_raises_error
# ✓ TestBankAccount.test_withdraw_zero_or_negative_raises_error
# ✓ TestCalculator.test_addition
# ✓ TestCalculator.test_division
# ✓ TestCalculator.test_division_by_zero
# ✓ TestCalculator.test_history_tracking
# ✓ TestCalculator.test_multiplication
# ✓ TestCalculator.test_subtraction
# ✓ TestStack.test_new_stack_is_empty
# ✓ TestStack.test_peek_does_not_remove
# ✓ TestStack.test_peek_empty_stack_raises_error
# ✓ TestStack.test_pop_empty_stack_raises_error
# ✓ TestStack.test_push_increases_size
# ✓ TestStack.test_push_pop_roundtrip
# ✓ TestStringProcessor.test_capitalize_words
# ✓ TestStringProcessor.test_count_words_empty
# ✓ TestStringProcessor.test_count_words_multiple_spaces
# ✓ TestStringProcessor.test_count_words_normal
# ✓ TestStringProcessor.test_reverse_empty_string
# ✓ TestStringProcessor.test_reverse_non_string_raises_error
# ✓ TestStringProcessor.test_reverse_normal_string
# ✓ TestStringProcessor.test_reverse_single_character
# ✓ TestStringProcessor.test_reverse_unicode
# <unittest.runner.TextTestResult run=30 errors=0 failures=0>

# %% [markdown]
# ## 🎯 Types of Tests
#
# Let's see the different types of tests in action:

# %%
# Run specific test cases
print("Running specific test cases...")
print("=" * 50)

# Test calculator operations
calc_suite = unittest.TestLoader().loadTestsFromTestCase(TestCalculator)
test_runner = unittest.TextTestRunner(verbosity=2)
test_runner.run(calc_suite)

print()
print("=" * 50)

# Test stack operations
stack_suite = unittest.TestLoader().loadTestsFromTestCase(TestStack)
test_runner.run(stack_suite)

print()
print("=" * 50)

# Test string operations
string_suite = unittest.TestLoader().loadTestsFromTestCase(TestStringProcessor)
test_runner.run(string_suite)

print()
print("=" * 50)

# Test bank account operations
bank_suite = unittest.TestLoader().loadTestsFromTestCase(TestBankAccount)
test_runner.run(bank_suite)
# Out:
# test_addition (chapter_04_testing.tests.test_testing_concepts.TestCalculator.test_addition)
# Test calculator addition. ... ok
# test_division (chapter_04_testing.tests.test_testing_concepts.TestCalculator.test_division)
# Test calculator division. ... ok
# test_division_by_zero (chapter_04_testing.tests.test_testing_concepts.TestCalculator.test_division_by_zero)
# Test division by zero raises error. ... ok
# test_history_tracking (chapter_04_testing.tests.test_testing_concepts.TestCalculator.test_history_tracking)
# Test that history is maintained correctly. ... ok
# test_multiplication (chapter_04_testing.tests.test_testing_concepts.TestCalculator.test_multiplication)
# Test calculator multiplication. ... ok
# test_subtraction (chapter_04_testing.tests.test_testing_concepts.TestCalculator.test_subtraction)
# Test calculator subtraction. ... ok
#
# ----------------------------------------------------------------------
# Ran 6 tests in 0.038s
#
# OK
# test_new_stack_is_empty (chapter_04_testing.tests.test_testing_concepts.TestStack.test_new_stack_is_empty)
# Test that a new stack is empty. ... ok
# test_peek_does_not_remove (chapter_04_testing.tests.test_testing_concepts.TestStack.test_peek_does_not_remove)
# Test that peek returns top item without removing it. ... ok
# test_peek_empty_stack_raises_error (chapter_04_testing.tests.test_testing_concepts.TestStack.test_peek_empty_stack_raises_error)
# Test that peeking empty stack raises IndexError. ... ok
# test_pop_empty_stack_raises_error (chapter_04_testing.tests.test_testing_concepts.TestStack.test_pop_empty_stack_raises_error)
# Test that popping empty stack raises IndexError. ... ok
# test_push_increases_size (chapter_04_testing.tests.test_testing_concepts.TestStack.test_push_increases_size)
# Test that push increases stack size. ... ok
# test_push_pop_roundtrip (chapter_04_testing.tests.test_testing_concepts.TestStack.test_push_pop_roundtrip)
# Test push and pop maintain order (LIFO). ... ok
#
# ----------------------------------------------------------------------
# Ran 6 tests in 0.005s
#
# OK
# test_capitalize_words (chapter_04_testing.tests.test_testing_concepts.TestStringProcessor.test_capitalize_words)
# Test capitalizing first letter of each word. ... ok
# test_count_words_empty (chapter_04_testing.tests.test_testing_concepts.TestStringProcessor.test_count_words_empty)
# Test counting words in empty string. ... ok
# test_count_words_multiple_spaces (chapter_04_testing.tests.test_testing_concepts.TestStringProcessor.test_count_words_multiple_spaces)
# Test handling multiple spaces between words. ... ok
# test_count_words_normal (chapter_04_testing.tests.test_testing_concepts.TestStringProcessor.test_count_words_normal)
# Test counting words in normal text. ... ok
# test_reverse_empty_string (chapter_04_testing.tests.test_testing_concepts.TestStringProcessor.test_reverse_empty_string)
# Test reversing an empty string. ... ok
# test_reverse_non_string_raises_error (chapter_04_testing.tests.test_testing_concepts.TestStringProcessor.test_reverse_non_string_raises_error)
# Test that non-string input raises TypeError. ... ok
# test_reverse_normal_string (chapter_04_testing.tests.test_testing_concepts.TestStringProcessor.test_reverse_normal_string)
# Test reversing a normal string. ... ok
# test_reverse_single_character (chapter_04_testing.tests.test_testing_concepts.TestStringProcessor.test_reverse_single_character)
# Test reversing a single character. ... ok
# test_reverse_unicode (chapter_04_testing.tests.test_testing_concepts.TestStringProcessor.test_reverse_unicode)
# Test reversing unicode strings. ... ok
#
# ----------------------------------------------------------------------
# Ran 9 tests in 0.026s
#
# OK
# test_balance_unchanged_after_failed_operations (chapter_04_testing.tests.test_testing_concepts.TestBankAccount.test_balance_unchanged_after_failed_operations)
# Test that balance doesn't change after failed operations. ... ok
# test_deposit_increases_balance (chapter_04_testing.tests.test_testing_concepts.TestBankAccount.test_deposit_increases_balance)
# Test that deposit increases balance. ... ok
# test_deposit_zero_or_negative_raises_error (chapter_04_testing.tests.test_testing_concepts.TestBankAccount.test_deposit_zero_or_negative_raises_error)
# Test that depositing zero or negative amounts raises error. ... ok
# test_initial_balance (chapter_04_testing.tests.test_testing_concepts.TestBankAccount.test_initial_balance)
# Test account starts with correct balance. ... ok
# test_negative_initial_balance_raises_error (chapter_04_testing.tests.test_testing_concepts.TestBankAccount.test_negative_initial_balance_raises_error)
# Test that negative initial balance raises ValueError. ... ok
# test_transaction_history (chapter_04_testing.tests.test_testing_concepts.TestBankAccount.test_transaction_history)
# Test that transactions are recorded in history. ... ok
# test_withdraw_decreases_balance (chapter_04_testing.tests.test_testing_concepts.TestBankAccount.test_withdraw_decreases_balance)
# Test that withdrawal decreases balance. ... ok
# test_withdraw_insufficient_funds_raises_error (chapter_04_testing.tests.test_testing_concepts.TestBankAccount.test_withdraw_insufficient_funds_raises_error)
# Test that withdrawing more than balance raises error. ...
# Running specific test cases...
# ==================================================
# ✓ TestCalculator.test_addition
# ✓ TestCalculator.test_division
# ✓ TestCalculator.test_division_by_zero
# ✓ TestCalculator.test_history_tracking
# ✓ TestCalculator.test_multiplication
# ✓ TestCalculator.test_subtraction
#
# ==================================================
# ✓ TestStack.test_new_stack_is_empty
# ✓ TestStack.test_peek_does_not_remove
# ✓ TestStack.test_peek_empty_stack_raises_error
# ✓ TestStack.test_pop_empty_stack_raises_error
# ✓ TestStack.test_push_increases_size
# ✓ TestStack.test_push_pop_roundtrip
#
# ==================================================
# ✓ TestStringProcessor.test_capitalize_words
# ✓ TestStringProcessor.test_count_words_empty
# ✓ TestStringProcessor.test_count_words_multiple_spaces
# ✓ TestStringProcessor.test_count_words_normal
# ✓ TestStringProcessor.test_reverse_empty_string
# ✓ TestStringProcessor.test_reverse_non_string_raises_error
# ✓ TestStringProcessor.test_reverse_normal_string
# ✓ TestStringProcessor.test_reverse_single_character
# ✓ TestStringProcessor.test_reverse_unicode
#
# ==================================================
# ✓ TestBankAccount.test_balance_unchanged_after_failed_operations
# ✓ TestBankAccount.test_deposit_increases_balance
# ✓ TestBankAccount.test_deposit_zero_or_negative_raises_error
# ✓ TestBankAccount.test_initial_balance
# ✓ TestBankAccount.test_negative_initial_balance_raises_error
# ✓ TestBankAccount.test_transaction_history
# ✓ TestBankAccount.test_withdraw_decreases_balance
# ✓ TestBankAccount.test_withdraw_insufficient_funds_raises_error
# ok
# test_withdraw_zero_or_negative_raises_error (chapter_04_testing.tests.test_testing_concepts.TestBankAccount.test_withdraw_zero_or_negative_raises_error)
# Test that withdrawing zero or negative amounts raises error. ... ok
#
# ----------------------------------------------------------------------
# Ran 9 tests in 0.045s
#
# OK
# ✓ TestBankAccount.test_withdraw_zero_or_negative_raises_error
# <unittest.runner.TextTestResult run=9 errors=0 failures=0>

# %% [markdown]
# ## 🔍 Debugging Techniques
#
# Let's explore some common debugging techniques:

# %%
# Debugging example - traceback analysis
def debug_example():
    try:
        x = 5
        y = "test"
        result = x + y  # This should fail
        return result
    except Exception as e:
        import traceback
        print(f"Error: {type(e).__name__}: {e}")
        print("\nStack Trace:")
        print(traceback.format_exc())

# Try to debug the error
debug_example()

# Fixing the error
def fixed_example():
    x = 5
    y = "test"
    result = str(x) + y  # Fixed by converting to string
    return result

print(f"\nFixed Result: {fixed_example()}")
# Out:
# Error: TypeError: unsupported operand type(s) for +: 'int' and 'str'
#
# Stack Trace:
# Traceback (most recent call last):
#   File "/var/folders/th/t5bmj7z97kx83tz9dxkwbz0m0000gn/T/ipykernel_87978/1917333446.py", line 6, in debug_example
#     result = x + y  # This should fail
#              ~~^~~
# TypeError: unsupported operand type(s) for +: 'int' and 'str'
#
#
# Fixed Result: 5test

# %% [markdown]
# ## 📈 Test Coverage
#
# Test coverage helps you understand what parts of your code are being tested. Let's check coverage:

# %%
# Check if coverage module is available
try:
    import coverage
    print("✅ Coverage module is available")
    
    # Run coverage analysis
    cov = coverage.Coverage()
    cov.start()
    
    # Run the tests
    test_suite = unittest.TestLoader().discover(
        os.path.join('../', 'chapter_04_testing', 'tests')
    )
    unittest.TextTestRunner().run(test_suite)
    
    cov.stop()
    cov.save()
    
    # Report coverage
    print("\nCoverage Report:")
    print("=" * 50)
    cov.report()
    
except ImportError:
    print("❌ Coverage module not available. Install with: pip install coverage")
except Exception as e:
    print(f"Error: {e}")
# Out:
# ❌ Coverage module not available. Install with: pip install coverage

# %% [markdown]
# ## 🔄 Test Driven Development (TDD) Example
#
# TDD is a development methodology where you write tests before you write the code. Let's see an example:

# %%
# Test for a new function that doesn't exist yet
class TestNewFunction(unittest.TestCase):
    """Tests for a new function - demonstrates TDD"""
    
    def test_reverse_string(self):
        """Test that a string is reversed correctly"""
        from chapter_04_testing.code.testing_concepts import StringProcessor
        processor = StringProcessor()
        self.assertEqual(processor.reverse("hello"), "olleh")
        self.assertEqual(processor.reverse(""), "")
        self.assertEqual(processor.reverse("a"), "a")
    
    def test_count_words(self):
        """Test that word counting works correctly"""
        from chapter_04_testing.code.testing_concepts import StringProcessor
        processor = StringProcessor()
        self.assertEqual(processor.count_words("hello world"), 2)
        self.assertEqual(processor.count_words(""), 0)
        self.assertEqual(processor.count_words("   test   with   spaces   "), 3)

# Run the TDD tests
print("Running TDD tests...")
print("=" * 50)
tdd_suite = unittest.TestLoader().loadTestsFromTestCase(TestNewFunction)
test_runner = unittest.TextTestRunner(verbosity=2)
test_runner.run(tdd_suite)
# Out:
# test_count_words (__main__.TestNewFunction.test_count_words)
# Test that word counting works correctly ... ok
# test_reverse_string (__main__.TestNewFunction.test_reverse_string)
# Test that a string is reversed correctly ... ok
#
# ----------------------------------------------------------------------
# Ran 2 tests in 0.003s
#
# OK
# Running TDD tests...
# ==================================================
# <unittest.runner.TextTestResult run=2 errors=0 failures=0>

# %% [markdown]
# ## 🎓 Chapter Summary
#
# In this chapter, you've learned:
# - **Testing Basics**: Importance of testing in software development
# - **Unit Testing**: Writing and running tests with `unittest` module
# - **Test Cases**: Creating test cases for functions and classes
# - **Assertions**: Different types of assertions for validation
# - **Exception Handling**: Testing expected exceptions
# - **Debugging**: Techniques to identify and fix issues
# - **TDD**: Test Driven Development approach
#
# ## 🔮 Next Steps
#
# Continue your journey with:
# - **Chapter 5**: Running Time Analysis
# - **Chapter 6**: Stacks and Queues
# - **Chapter 7**: Deques and Linked Lists
